# %%
num1=10

# %%
num2=50

# %%
add=num1+num2

# %%
print("add")
print(add)
# Out:
# add
# 60

# %%
Thenumeber1=10

# %%
Thenumber1=10
Thenumber2=20
TheAnswer=Thenumber1+Thenumber2
print("The addition of two numbers")
print(Thenumber1)
print(Thenumber2)
print(TheAnswer)
# Out:
# The addition of two numbers
# 10
# 20
# 30

# %%
Thenumber1=10
Thenumber2=20
TheAnswer=Thenumber1+Thenumber2
print("The addition of two numbers")
print("The number1:",Thenumber1)
print("The number2:",Thenumber2)
print("The Answer:",TheAnswer)
# Out:
# The addition of two numbers
# The number1: 10
# The number2: 20
# The Answer: 30

# %%
input("what is value:")

# %%
number5=input("what is number5:")

# %%
number5=input("what is value:")
