# %%
print ("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
Add=Num1+Num2
print ("Add-",(Add))
# Out:
# Add- 40

# %%
Body_Mass_Index=int(input("Enter the BMI Index:"))
# Out:
# Enter the BMI Index: 34

# %%
if(Body_Mass_Index<18.5):
            print("Under Weight")
elif(Body_Mass_Index<24.9):
            print("Normal Weight")
elif(Body_Mass_Index<29.9):
            print("Not Normal Weight")
else: 
    print("Very OverWeight")
# Out:
# Very OverWeight
