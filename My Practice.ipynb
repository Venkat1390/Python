# %%
name="venkatesh"
age=35
city="chennai"

# %%
print(name)
print(age)
print(city)

# %%
salary=50000
salary=60000
salary=70000
print(salary)

# %%
company="TCS"
print(company)
print("company")
# Out:
# TCS
# company

# %%
country="India"
My_country=country
print(My_country)
# Out:
# India

# %%
x=100
y=x
x=200
z=x
print(x)
print(y)
print(z)
# Out:
# 200
# 100
# 200

# %%
Name=input("Enter your name:")
# Out:
# Enter your name: Venkatesh

# %%
print("Hello",Name)
# Out:
# Hello Venkatesh

# %%
ame=input("Enter your name")
City=input("Your City")
print("Hello",ame)
print("You are from",City)
# Out:
# Enter your name Venkatesh R
# Your City Chennai
# Hello Venkatesh R
# You are from Chennai
