# %%
Aging_Value=int(input("your age is"))
print("Your age is",Aging_Value)
# Out:
# your age is 35
# Your age is 35

# %%
First=int(input("Enter First Number:"))
Second=int(input("Enter Second Number:"))
print("Enter First Number:",First)
print("Enter Second Number:",Second)
add=(First+Second)
print(add)
# Out:
# Enter First Number: 20
# Enter Second Number: 30
# Enter First Number: 20
# Enter Second Number: 30
# 50

# %%
marks=75
if(marks>=50):
    print("Pass")
# Out:
# Pass
