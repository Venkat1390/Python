# %%
value=int(input("what is the value:"))
# Out:
# what is the value:60

# %%
value2=int(input("what is the value2:"))
# Out:
# what is the value2:50

# %%
answer=(value+value2)

# %%
print("answer:",answer)
# Out:
# answer: 110
